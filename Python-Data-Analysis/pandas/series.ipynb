# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,20,30]
array=np.array([10,20,30])
d={'A':10,'B':20,'C':30}

# %%
pd.Series(my_list,index=labels) #creating the series
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(array)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# A    10
# B    20
# C    30
# dtype: int64
