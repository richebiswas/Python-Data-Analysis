# %%
import matplotlib .pyplot as plt
import numpy as np

# %%
categories=["Grains","Fruits","Vegtables","Proteins","Dairy","Sweets"]
values=np.array([4,2,3,5,6,1])

# %%
plt.bar(categories,values,color="skyblue")  #vertical
#plt.barh(categories,values,color="skyblue")  #horizontal

plt.title("Daily Consumption")
plt.xlabel("Food")


plt.ylabel("Quantity")

plt.show()
